# %%
'''
Name: Abhinesh Gangwar
Section: G
University Roll Number: 2028614
'''
def bfs(st,go,graph):
  q=[[st]]
  v={st}
  while q:
    path=q.pop(0)
    node=path[-1]
    nodes.append(node)
    if node==go:
      return path
    for i in graph[node]:
      if i not in v:
        q.append(path+[i])
        v.add(i)
  return False

# %%
graph={"A":["B","C"],"B":["E","D","F","A"],"C":["A","D","F"],"D":["B","E","C","F"],"E":["D","B","F"],"F":["E","C","B","D"]}
Start=input("enter the start goal:").strip().upper()
Goal=input("enter the end goal:").strip().upper()
nodes=[]
path=bfs(Start,Goal,graph)
print(nodes)
print("The Path is :\n",path)
# Out:
# enter the start goal: A
# enter the end goal: D
# ['A', 'B', 'C', 'E', 'D']
# The Path is :
#  ['A', 'B', 'D']

# %%
graph={}
for i in range(6):
    a=input("enter unique node :")
    b=int(input("enter no of  edges :"))
    l=[]
    for i in range(b):
        c=input("enter the egde:")
        l.append(c)
    graph[a]=l
nodes=[]
path=bfs(Start,Goal,graph)
print("Transverse nodes :",nodes)
print("The Path is :\n",path)
# Out:
# enter unique node : A
# enter no of  edges : 2
# enter the egde: B
# enter the egde: C
# enter unique node : B
# enter no of  edges : 3
# enter the egde: D
# enter the egde: E
# enter the egde: F
# enter unique node : C
# enter no of  edges : 2
# enter the egde: D
# enter the egde: E
# enter unique node : D
# enter no of  edges : 2
# enter the egde: E
# enter the egde: F
# enter unique node : E
# enter no of  edges : 1
# enter the egde: F
# enter unique node : F
# enter no of  edges : 0
# Transverse Nodes : ['A', 'B', 'C', 'D']
# The Path is :
#  ['A', 'B', 'D']
