# %%
import pandas as pd
df=pd.DataFrame({"type":["house","flat","flat","house","flat","house","flat","house","house","flat","house","flat","flat","house","flat","house","house","flat","flat","house"],"size":[3,2,1,4,3,4,3,4,2,1,3,4,5,1,2,1,2,3,4,1],"area":[300,200,100,400,300,400,300,400,200,100,300,400,500,100,200,100,200,300,400,100],"price":[35, 25, 15, 50, 30, 50, 35, 55, 25, 15, 35, 50, 70, 15, 25, 15, 25, 40, 55, 15]})
odf=df.copy()
df
# Out:
#      type  size  area  price
# 0   house     3   300     35
# 1    flat     2   200     25
# 2    flat     1   100     15
# 3   house     4   400     50
# 4    flat     3   300     30
# 5   house     4   400     50
# 6    flat     3   300     35
# 7   house     4   400     55
# 8   house     2   200     25
# 9    flat     1   100     15
# 10  house     3   300     35
# 11   flat     4   400     50
# 12   flat     5   500     70
# 13  house     1   100     15
# 14   flat     2   200     25
# 15  house     1   100     15
# 16  house     2   200     25
# 17   flat     3   300     40
# 18   flat     4   400     55
# 19  house     1   100     15

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure()
sb.lineplot(x="area",y="price",data=odf,label="Orignal")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.show()

# %%
plt.figure()
plt.title("Orignal")
sb.barplot(x="area",y="price",data=odf,hue="price",color="red")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.show()
# Out:
# /tmp/ipython-input-3747517226.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sb.barplot(x="area",y="price",data=odf,hue="price",color="red")

# %%
for i in df["area"]:
  x=(i-min(df["area"]))/(max(df["area"])-min(df["area"]))
  df["area"]=df["area"].replace(i,x)
for i in df["price"]:
  x=(i-min(df["price"]))/(max(df["price"])-min(df["price"]))
  df["price"]=df["price"].replace(i,x)
df
# Out:
#      type  size      area     price
# 0   house     3  0.500000  0.363636
# 1    flat     2  0.399399  0.353786
# 2    flat     1  0.199360  0.210294
# 3   house     4  0.799920  0.713425
# 4    flat     3  0.500000  0.426850
# 5   house     4  0.799920  0.713425
# 6    flat     3  0.500000  0.363636
# 7   house     4  0.799920  0.785069
# 8   house     2  0.399399  0.353786
# 9    flat     1  0.199360  0.210294
# 10  house     3  0.500000  0.363636
# 11   flat     4  0.799920  0.713425
# 12   flat     5  1.000000  1.000000
# 13  house     1  0.199360  0.210294
# 14   flat     2  0.399399  0.353786
# 15  house     1  0.199360  0.210294
# 16  house     2  0.399399  0.353786
# 17   flat     3  0.500000  1.000000
# 18   flat     4  0.799920  0.785069
# 19  house     1  0.199360  0.210294

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure()
sb.lineplot(x="area",y="price",data=df,label="Normalised")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.show()

# %%
plt.figure()
sb.scatterplot(x="area",y="price",data=df,label="Normalised")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.show()

# %%
plt.figure()
plt.title("Orignal")
sb.barplot(x="area",y="price",data=odf,hue="price")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.figure()
plt.title("Normalised")
sb.barplot(x="area",y="price",data=df,hue="price")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.show()

# %%
plt.figure()
sb.histplot(x="area",y="price",data=df,hue="price",label="Normalised",color="cool")
plt.xlabel("Area in sq. ft")
plt.ylabel("Price in Lakhs")
plt.title("Normalised")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-892156391.py:6: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
# /tmp/ipython-input-892156391.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
